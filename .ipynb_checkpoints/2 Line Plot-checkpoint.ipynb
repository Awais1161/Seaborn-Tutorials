# %%
Syntex

# import seaborn as sns 
# import matplotlib.pyplot as plt

# data=sns.load_dataset(' ')
# sns.lineplot(x='', y='',data=data)

# plt.show()

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

v=[1,2,3,4,5,6,7]
v1=[2,3,4,1,5,6,7]

plt.plot(v,v1)

plt.show()

# %%
v=[1,2,3,4,5,6,7]
v1=[2,3,4,1,5,6,7]

sns.lineplot(x=v, y=v1) 

plt.show()   # this graph is 100 percent same as in matplotlib

# %%
var=[1,2,3,4,5,6,7]
var_1=[2,3,4,1,5,6,7]

sns.lineplot(x='var', y='var1')  # not work because seaborn work on dataset

# %%
import pandas as pd

var=[1,2,3,4,5,6,7]
var_1=[2,3,4,1,5,6,7]

x_1=pd.DataFrame({'var':var, 'var_1':var_1})

sns.lineplot(x='var', y='var_1', data=x_1) 

plt.show()

# %%
y_1=sns.load_dataset('penguins')
y_1
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 3            NaN     NaN
# 4         3450.0  Female
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [344 rows x 7 columns]

# %%
sns.lineplot(x='bill_length_mm', y='flipper_length_mm', data=y_1) 

plt.show()

# %%
sns.lineplot(x='bill_length_mm', y='flipper_length_mm', data=y_1,hue= 'sex') 

plt.show()   # legend is automatically that was not in matplotlib

# %%
sns.lineplot(x='bill_length_mm', y='flipper_length_mm', data=y_1,hue= 'sex',size=10) 

plt.show()

# %%
sns.lineplot(x='bill_length_mm', y='flipper_length_mm', data=y_1,hue= 'sex',style='sex') 

plt.show()

# %%
sns.lineplot(x='bill_length_mm', y='flipper_length_mm', data=y_1,hue= 'sex',style='sex',
             palette='B') # Put any alphabet list of cpolors wiil be displayed in erroe box

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\seaborn\palettes.py:206, in color_palette(palette, n_colors, desat, as_cmap)
#     204 try:
#     205     # Perhaps a named matplotlib colormap?
# --> 206     palette = mpl_palette(palette, n_colors, as_cmap=as_cmap)
#     207 except ValueError:
#
# File ~\anaconda3\lib\site-packages\seaborn\palettes.py:443, in mpl_palette(name, n_colors, as_cmap)
#     442 else:
# --> 443     cmap = mpl.cm.get_cmap(name)
#     445 if name in MPL_QUAL_PALS:
#
# File ~\anaconda3\lib\site-packages\matplotlib\cm.py:286, in get_cmap(name, lut)
#     285     return name
# --> 286 _api.check_in_list(sorted(_cmap_registry), name=name)
#     287 if lut is None:
#
# File ~\anaconda3\lib\site-packages\matplotlib\_api\__init__.py:129, in check_in_list(_values, _print_supported_values, **kwargs)
#     128     msg += f"; supported values are {', '.join(map(repr, values))}"
# --> 129 raise ValueError(msg)
#
# ValueError: 'B' is not a valid value for name; supported values are 'Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'crest', 'crest_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'flare', 'flare_r', 'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_heat', 'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'hot', 'hot_r', 'hsv', 'hsv_r', 'icefire', 'icefire_r', 'inferno', 'inferno_r', 'jet', 'jet_r', 'magma', 'magma_r', 'mako', 'mako_r', 'nipy_spectral', 'nipy_spectral_r', 'ocean', 'ocean_r', 'pink', 'pink_r', 'plasma', 'plasma_r', 'prism', 'prism_r', 'rainbow', 'rainbow_r', 'rocket', 'rocket_r', 'seismic', 'seismic_r', 'spring', 'spring_r', 'summer', 'summer_r', 'tab10', 'tab10_r', 'tab20', 'tab20_r', 'tab20b', 'tab20b_r', 'tab20c', 'tab20c_r', 'terrain', 'terrain_r', 'turbo', 'turbo_r', 'twilight', 'twilight_r', 'twilight_shifted', 'twilight_shifted_r', 'viridis', 'viridis_r', 'vlag', 'vlag_r', 'winter', 'winter_r'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [20], in <cell line: 1>()
# ----> 1 sns.lineplot(x='bill_length_mm', y='flipper_length_mm', data=y_1,hue= 'sex',style='sex', palette='B')
#       3 plt.show()
#
# File ~\anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~\anaconda3\lib\site-packages\seaborn\relational.py:698, in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#     691 variables = _LinePlotter.get_semantics(locals())
#     692 p = _LinePlotter(
#     693     data=data, variables=variables,
#     694     estimator=estimator, ci=ci, n_boot=n_boot, seed=seed,
#     695     sort=sort, err_style=err_style, err_kws=err_kws, legend=legend,
#     696 )
# --> 698 p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     699 p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#     700 p.map_style(markers=markers, dashes=dashes, order=style_order)
#
# File ~\anaconda3\lib\site-packages\seaborn\_core.py:53, in SemanticMapping.map(cls, plotter, *args, **kwargs)
#      50 def map(cls, plotter, *args, **kwargs):
#      51     # This method is assigned the __init__ docstring
#      52     method_name = "_{}_map".format(cls.__name__[:-7].lower())
# ---> 53     setattr(plotter, method_name, cls(plotter, *args, **kwargs))
#      54     return plotter
#
# File ~\anaconda3\lib\site-packages\seaborn\_core.py:118, in HueMapping.__init__(self, plotter, palette, order, norm)
#     115 elif map_type == "categorical":
#     117     cmap = norm = None
# --> 118     levels, lookup_table = self.categorical_mapping(
#     119         data, palette, order,
#     120     )
#     122 # --- Option 3: datetime mapping
#     123
#     124 else:
#     125     # TODO this needs actual implementation
#     126     cmap = norm = None
#
# File ~\anaconda3\lib\site-packages\seaborn\_core.py:207, in HueMapping.categorical_mapping(self, data, palette, order)
#     205         colors = palette
#     206     else:
# --> 207         colors = color_palette(palette, n_colors)
#     209     lookup_table = dict(zip(levels, colors))
#     211 return levels, lookup_table
#
# File ~\anaconda3\lib\site-packages\seaborn\palettes.py:208, in color_palette(palette, n_colors, desat, as_cmap)
#     206             palette = mpl_palette(palette, n_colors, as_cmap=as_cmap)
#     207         except ValueError:
# --> 208             raise ValueError("%s is not a valid palette name" % palette)
#     210 if desat is not None:
#     211     palette = [desaturate(c, desat) for c in palette]
#
# ValueError: B is not a valid palette name

# %%
sns.lineplot(x='bill_length_mm', y='flipper_length_mm', data=y_1,hue= 'sex',style='sex',palette='Accent') 

plt.show()

# %%
sns.lineplot(x='bill_length_mm', y='flipper_length_mm', data=y_1,hue= 'sex',style='sex',palette='rocket') 

plt.show()

# %%
sns.lineplot(x='bill_length_mm', y='flipper_length_mm', data=y_1,hue= 'sex',
             style='sex',palette='rocket',markers=['o','>']) 

plt.show()

# %%
y_1=sns.load_dataset('penguins').head(20)
y_1
# Out:
#    species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0   Adelie  Torgersen            39.1           18.7              181.0
# 1   Adelie  Torgersen            39.5           17.4              186.0
# 2   Adelie  Torgersen            40.3           18.0              195.0
# 3   Adelie  Torgersen             NaN            NaN                NaN
# 4   Adelie  Torgersen            36.7           19.3              193.0
# 5   Adelie  Torgersen            39.3           20.6              190.0
# 6   Adelie  Torgersen            38.9           17.8              181.0
# 7   Adelie  Torgersen            39.2           19.6              195.0
# 8   Adelie  Torgersen            34.1           18.1              193.0
# 9   Adelie  Torgersen            42.0           20.2              190.0
# 10  Adelie  Torgersen            37.8           17.1              186.0
# 11  Adelie  Torgersen            37.8           17.3              180.0
# 12  Adelie  Torgersen            41.1           17.6              182.0
# 13  Adelie  Torgersen            38.6           21.2              191.0
# 14  Adelie  Torgersen            34.6           21.1              198.0
# 15  Adelie  Torgersen            36.6           17.8              185.0
# 16  Adelie  Torgersen            38.7           19.0              195.0
# 17  Adelie  Torgersen            42.5           20.7              197.0
# 18  Adelie  Torgersen            34.4           18.4              184.0
# 19  Adelie  Torgersen            46.0           21.5              194.0
#
#     body_mass_g     sex
# 0        3750.0    Male
# 1        3800.0  Female
# 2        3250.0  Female
# 3           NaN     NaN
# 4        3450.0  Female
# 5        3650.0    Male
# 6        3625.0  Female
# 7        4675.0    Male
# 8        3475.0     NaN
# 9        4250.0     NaN
# 10       3300.0     NaN
# 11       3700.0     NaN
# 12       3200.0  Female
# 13       3800.0    Male
# 14       4400.0    Male
# 15       3700.0  Female
# 16       3450.0  Female
# 17       4500.0    Male
# 18       3325.0  Female
# 19       4200.0    Male

# %%
sns.lineplot(x='bill_length_mm', y='flipper_length_mm', data=y_1,hue= 'sex',
             style='sex',palette='rocket',markers=['o','>']) 

plt.show()

# %%
sns.lineplot(x='bill_length_mm', y='flipper_length_mm', data=y_1,hue= 'sex',
             style='sex',palette='rocket',markers=['o','>'],dashes=False) 

plt.show()

# %%
sns.lineplot(x='bill_length_mm', y='flipper_length_mm', data=y_1,hue= 'sex',
             style='sex',palette='rocket',markers=['o','>'],
             dashes=False,legend=False) # jb k matplotlib ma legend lanay k lia legend ki zroorat thi

plt.show()

# %%
sns.lineplot(x='bill_length_mm', y='flipper_length_mm', data=y_1,hue= 'sex',
             style='sex',palette='rocket',markers=['o','>'],
             dashes=False,legend='f') # koi b enter kr k error box ma all legends can be viwed

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [29], in <cell line: 1>()
# ----> 1 sns.lineplot(x='bill_length_mm', y='flipper_length_mm', data=y_1,hue= 'sex',
#       2              style='sex',palette='rocket',markers=['o','>'],
#       3              dashes=False,legend='f')
#       5 plt.show()
#
# File ~\anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~\anaconda3\lib\site-packages\seaborn\relational.py:710, in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#     706     return ax
#     708 p._attach(ax)
# --> 710 p.plot(ax, kwargs)
#     711 return ax
#
# File ~\anaconda3\lib\site-packages\seaborn\relational.py:559, in _LinePlotter.plot(self, ax, kws)
#     557 self._add_axis_labels(ax)
#     558 if self.legend:
# --> 559     self.add_legend_data(ax)
#     560     handles, _ = ax.get_legend_handles_labels()
#     561     if handles:
#
# File ~\anaconda3\lib\site-packages\seaborn\relational.py:200, in _RelationalPlotter.add_legend_data(self, ax)
#     198 if isinstance(verbosity, str) and verbosity not in ["auto", "brief", "full"]:
#     199     err = "`legend` must be 'auto', 'brief', 'full', or a boolean."
# --> 200     raise ValueError(err)
#     201 elif verbosity is True:
#     202     verbosity = "auto"
#
# ValueError: `legend` must be 'auto', 'brief', 'full', or a boolean.

# %%
sns.lineplot(x='bill_length_mm', y='flipper_length_mm', data=y_1,hue= 'sex',
             style='sex',palette='rocket',markers=['o','>'],
             dashes=False,legend='auto') 

plt.show()

# %%
sns.lineplot(x='bill_length_mm', y='flipper_length_mm', data=y_1,hue= 'sex',
             style='sex',palette='rocket',markers=['o','>'],
             dashes=False,legend='auto') 

plt.grid()
plt.title('python')
plt.show()
