# %%
# Syntex

# sns.barplot(x=''. y='', data=df)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
var=sns.load_dataset('penguins')
var
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.barplot(x=var.island, y=var.bill_length_mm)
plt.show()

# %%
sns.barplot(x=var['island'], y=var['bill_length_mm'])    # same
plt.show()

# %%
sns.barplot(x='island', y='bill_length_mm',data=var) # Same
plt.show()

# %%
sns.barplot(x='island', y='bill_length_mm',data=var, hue='sex') 
plt.show()

# %%
o=['Dream', 'Torgersen', 'Biscoe']
sns.barplot(x='island', y='bill_length_mm',data=var, hue='sex', order=o) 
plt.show()

# %%
o=['Dream', 'Torgersen', 'Biscoe']
sns.barplot(x='island', y='bill_length_mm',data=var, hue='sex', order=o, hue_order=['Female', 'Male']) 
plt.show()

# %%
o=['Dream', 'Torgersen', 'Biscoe']
sns.barplot(x='island', y='bill_length_mm',data=var, hue='sex'
            , order=o, hue_order=['Female', 'Male'],ci=100) 
plt.show()

# %%
o=['Dream', 'Torgersen', 'Biscoe']
sns.barplot(x='island', y='bill_length_mm',data=var, hue='sex'
            , order=o, hue_order=['Female', 'Male'],ci=100, n_boot=100) # n_boot ki smj ni ai
plt.show()

# %%
o=['Dream', 'Torgersen', 'Biscoe']
sns.barplot(x='island', y='bill_length_mm',data=var, hue='sex'
            , order=o, hue_order=['Female', 'Male'],ci=100, n_boot=100, orient='v') # by default vertical
plt.show()

# %%
o=['Dream', 'Torgersen', 'Biscoe']
sns.barplot(x='island', y='bill_length_mm',data=var, hue='sex'
            , order=o, hue_order=['Female', 'Male'],ci=100,
            n_boot=100, orient='h')  # error because both x and y should be numeric not catogorical as y
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [24], in <cell line: 2>()
#       1 o=['Dream', 'Torgersen', 'Biscoe']
# ----> 2 sns.barplot(x='island', y='bill_length_mm',data=var, hue='sex'
#       3             , order=o, hue_order=['Female', 'Male'],ci=100, n_boot=100, orient='h')
#       4 plt.show()
#
# File ~\anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# ...

# %%
sns.barplot(x='bill_depth_mm', y='bill_length_mm',data=var, orient='v') 
plt.show()

# %%
sns.barplot(x='bill_depth_mm', y='bill_length_mm',data=var, orient='h') 
plt.show()

# %%
sns.barplot(x='island', y='bill_length_mm',data=var) 
plt.show()

# %%
sns.barplot(x='island', y='bill_length_mm',data=var, color='g') 
plt.show()

# %%
o=['Dream', 'Torgersen', 'Biscoe']
sns.barplot(x='island', y='bill_length_mm',data=var, hue='sex'
            , order=o, hue_order=['Female', 'Male'],ci=100, n_boot=100, orient='v', palette='d') 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\seaborn\palettes.py:206, in color_palette(palette, n_colors, desat, as_cmap)
#     204 try:
#     205     # Perhaps a named matplotlib colormap?
# --> 206     palette = mpl_palette(palette, n_colors, as_cmap=as_cmap)
#     207 except ValueError:
#
# File ~\anaconda3\lib\site-packages\seaborn\palettes.py:443, in mpl_palette(name, n_colors, as_cmap)
#     442 else:
# --> 443     cmap = mpl.cm.get_cmap(name)
#     445 if name in MPL_QUAL_PALS:
#
# File ~\anaconda3\lib\site-packages\matplotlib\cm.py:286, in get_cmap(name, lut)
#     285     return name
# --> 286 _api.check_in_list(sorted(_cmap_registry), name=name)
#     287 if lut is None:
#
# File ~\anaconda3\lib\site-packages\matplotlib\_api\__init__.py:129, in check_in_list(_values, _print_supported_values, **kwargs)
# ...

# %%
o=['Dream', 'Torgersen', 'Biscoe']
sns.barplot(x='island', y='bill_length_mm',data=var, hue='sex'
            , order=o, hue_order=['Female', 'Male'],ci=100, n_boot=100, orient='v', palette='d') 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\seaborn\palettes.py:206, in color_palette(palette, n_colors, desat, as_cmap)
#     204 try:
#     205     # Perhaps a named matplotlib colormap?
# --> 206     palette = mpl_palette(palette, n_colors, as_cmap=as_cmap)
#     207 except ValueError:
#
# File ~\anaconda3\lib\site-packages\seaborn\palettes.py:443, in mpl_palette(name, n_colors, as_cmap)
#     442 else:
# --> 443     cmap = mpl.cm.get_cmap(name)
#     445 if name in MPL_QUAL_PALS:
#
# File ~\anaconda3\lib\site-packages\matplotlib\cm.py:286, in get_cmap(name, lut)
#     285     return name
# --> 286 _api.check_in_list(sorted(_cmap_registry), name=name)
#     287 if lut is None:
#
# File ~\anaconda3\lib\site-packages\matplotlib\_api\__init__.py:129, in check_in_list(_values, _print_supported_values, **kwargs)
# ...

# %%
o=['Dream', 'Torgersen', 'Biscoe']
sns.barplot(x='island', y='bill_length_mm',data=var, hue='sex'
            , order=o, hue_order=['Female', 'Male'],ci=100, n_boot=100, orient='v', palette='gist_ncar') 
plt.show()

# %%
o=['Dream', 'Torgersen', 'Biscoe']
sns.barplot(x='island', y='bill_length_mm',data=var, hue='sex'
            , order=o, hue_order=['Female', 'Male'],ci=100, n_boot=100, orient='v', palette='gist_ncar', saturation=0.3) 
plt.show()

# %%
o=['Dream', 'Torgersen', 'Biscoe']
sns.barplot(x='island', y='bill_length_mm',data=var, hue='sex'
            , order=o, hue_order=['Female', 'Male'],ci=100, n_boot=100, orient='v',
            palette='gist_ncar', saturation=0.3, errcolor='g',errwidth=12) 
plt.show()

# %%
o=['Dream', 'Torgersen', 'Biscoe']
sns.barplot(x='island', y='bill_length_mm',data=var, hue='sex'
            , order=o, hue_order=['Female', 'Male'],ci=100, n_boot=100, orient='v',
            palette='gist_ncar', saturation=0.3, errcolor='g',capsize=0.5) 
plt.show()

# %%
o=['Dream', 'Torgersen', 'Biscoe']
sns.barplot(x='island', y='bill_length_mm',data=var, hue='sex'
            , order=o, hue_order=['Female', 'Male'],ci=100, n_boot=100, orient='v',
            palette='gist_ncar', saturation=0.3, errcolor='g',dodge=False) # 1 , 2sray k uper superimpose
plt.show()

# %%
o=['Dream', 'Torgersen', 'Biscoe']
sns.barplot(x='island', y='bill_length_mm',data=var, hue='sex'
            , order=o, hue_order=['Female', 'Male'],ci=100, n_boot=100, orient='v',
            palette='gist_ncar', saturation=0.3, errcolor='g',alpha=0.5) 
plt.show()

# %%
sns.set(style='darkgrid')
o=['Dream', 'Torgersen', 'Biscoe']
sns.barplot(x='island', y='bill_length_mm',data=var, hue='sex'
            , order=o, hue_order=['Female', 'Male'],ci=100, n_boot=100, orient='v',
            palette='gist_ncar', saturation=0.3, errcolor='g',alpha=0.5) 
plt.show()

# %%
sns.set(style='dark')
o=['Dream', 'Torgersen', 'Biscoe']
sns.barplot(x='island', y='bill_length_mm',data=var, hue='sex'
            , order=o, hue_order=['Female', 'Male'],ci=100, n_boot=100, orient='v',
            palette='gist_ncar', saturation=0.3, errcolor='g',alpha=0.5) 
plt.show()
