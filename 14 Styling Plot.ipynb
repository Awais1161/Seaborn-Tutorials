# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
var=sns.load_dataset('tips')
var
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.boxplot(y=var['total_bill'])
plt.show()

# %%
sns.barplot(x='day', y='total_bill', data=var)
plt.show()

# %%
sns.barplot(x='day', y='total_bill', data=var)
plt.grid()
plt.show()

# %%
sns.set_style('white')   # no change bcz of by default
sns.barplot(x='day', y='total_bill', data=var) 

plt.show()

# %%
sns.set_style('dark')    # background
sns.barplot(x='day', y='total_bill', data=var) 

plt.show()

# %%
sns.set_style('whitegrid')    
sns.barplot(x='day', y='total_bill', data=var) 

plt.show()

# %%
sns.set_style('darkgrid')    
sns.barplot(x='day', y='total_bill', data=var) 

plt.show()

# %%
sns.set_style('ticks')  # default  
sns.barplot(x='day', y='total_bill', data=var) 

plt.show()

# %%
sns.set_style('darkgrid')    
sns.barplot(x='day', y='total_bill', data=var) 
plt.grid()
plt.show()

# %%
sns.set_style('white')    
sns.barplot(x='day', y='total_bill', data=var) 

plt.show()

# %%
sns.set_style('white')    
sns.barplot(x='day', y='total_bill', data=var) 
sns.despine()
plt.show()

# %%
sns.set_style('white') 
plt.figure(figsize=(3,12))  # width:height
sns.barplot(x='day', y='total_bill', data=var) 
sns.despine()
plt.show()

# %%
sns.set_style('white') 
plt.figure(figsize=(12,3))
sns.barplot(x='day', y='total_bill', data=var) 
sns.despine()
plt.show()

# %%
sns.set_style('white') 
plt.figure(figsize=(12,15)) 
sns.barplot(x='day', y='total_bill', data=var) 
sns.despine()
plt.show()

# %%
sns.set_style('white') 
sns.set_context('poster') # poster means a style(many kinds k styles hn)
sns.barplot(x='day', y='total_bill', data=var) 

plt.show()

# %%
sns.set_style('white') 
sns.set_context('paper') 
sns.barplot(x='day', y='total_bill', data=var) 

plt.show()

# %%
sns.set_style('white') 
sns.set_context('poster',font_scale=2)
sns.barplot(x='day', y='total_bill', data=var) 

plt.show()

# %%
sns.set_style('white') 
sns.set_context('paper') 
sns.barplot(x='day', y='total_bill', data=var ,color='r') 

plt.show()
